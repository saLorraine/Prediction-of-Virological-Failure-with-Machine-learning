# %% [markdown]
# In \[1\]:
#
#     import pandas as pd
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import numpy as np
#     %matplotlib inline
#     import warnings
#     warnings.filterwarnings ('ignore')
#
# In \[2\]:
#
#     import os
#
# In \[3\]:
#
#     os.getcwd()
#
# Out\[3\]:
#
#     '/Users/lorraine'
#
# In \[4\]:
#
#     path = '/Users/lorraine'+'Desktop/vl.xlsx'
#
# In \[5\]:
#
#     import openpyxl
#
# In \[ \]:
#
#
#
# # LOAD DATA<a href="#LOAD-DATA" class="anchor-link">¶</a>
#
# In \[6\]:
#
#     Viral_df = ("vl.xlsx")
#
# In \[7\]:
#
#     Viral_df = pd.read_excel('vl.xlsx')
#
# In \[8\]:
#
#     print(Viral_df.shape)
#
#     (10677, 29)
#
# In \[9\]:
#
#     pd.set_option('display.max_columns',30)
#
# In \[10\]:
#
#     Viral_df.head()
#
# Out\[10\]:
#
# |     | PatientId | Sex | AGE | Religion  | Occupation | EducationalLevelAttained | CurrentMaritalStatus | ViralLoad_Result | ViralLoad_date | ArtStartDate | Duration_on_art_Months | Enrolled_In_Care_date | Who_Stage | BaseLine_CD4_date | Baseline_CD4_count | Recent_CD4_date | Recent_CD4_count | Last_Weight_Recorded | First_Weight_Recorded | Current_regimen | Current_regimen_date | first_regimen   | first_regimen_date | Client_had_Cotrimoxazole_before | Disclosed_Status | functional_status     | PatientGUID                      | DaysLate_for_Pharm | Presence_of_OIs |
# |-----|-----------|-----|-----|-----------|------------|--------------------------|----------------------|------------------|----------------|--------------|------------------------|-----------------------|-----------|-------------------|--------------------|-----------------|------------------|----------------------|-----------------------|-----------------|----------------------|-----------------|--------------------|---------------------------------|------------------|-----------------------|----------------------------------|--------------------|-----------------|
# | 0   | 821360    | M   | 42  | CHRISTIAN | NaN        | Grade 12                 | M                    | 0                | 2021-03-27     | 2015-04-01   | 80.0                   | 2015-03-05            | NaN       | 2018-11-30        | NaN                | 2018-11-30      | NaN              | NaN                  | NaN                   | TDF + 3TC + DTG | 2022-02-02           | EFV + FTC + TDF | 2015-04-01         | Yes                             | NaN              | NaN                   | 8a1abf1cc08b47d38f5bea565fab9008 | 0.0                | NaN             |
# | 1   | 690464    | F   | 64  | CHRISTIAN | NaN        | Grade 7                  | D                    | 0                | 2021-02-10     | 2017-05-09   | 55.0                   | 2017-05-09            | NaN       | NaT               | NaN                | NaT             | NaN              | 75.0                 | NaN                   | TDF + 3TC + DTG | 2022-03-25           | EFV + FTC + TDF | 2017-05-09         | Yes                             | NaN              | NaN                   | 741bac5a878c4351bbeca0f3512d45bf | 0.0                | NaN             |
# | 2   | 294829    | F   | 30  | CHRISTIAN | NaN        | COLLEGE/UNIVERSITY       | S                    | 0                | 2020-05-08     | 2020-05-08   | 19.0                   | 2020-05-08            | NaN       | NaT               | NaN                | NaT             | NaN              | NaN                  | NaN                   | TDF + 3TC + DTG | 2022-03-04           | TDF + 3TC + DTG | 2020-05-08         | NaN                             | NaN              | Healthy, able to work | 318e6930459b44b3bdea5f265674d409 | 0.0                | No              |
# | 3   | 294829    | F   | 30  | CHRISTIAN | NaN        | COLLEGE/UNIVERSITY       | S                    | 0                | 2021-09-03     | 2020-05-08   | 19.0                   | 2020-05-08            | NaN       | NaT               | NaN                | NaT             | NaN              | NaN                  | NaN                   | TDF + 3TC + DTG | 2022-03-04           | TDF + 3TC + DTG | 2020-05-08         | NaN                             | NaN              | Healthy, able to work | 318e6930459b44b3bdea5f265674d409 | 0.0                | No              |
# | 4   | 887668    | M   | 39  | CHRISTIAN | NaN        | Grade 9                  | S                    | 0                | 2021-01-20     | 2017-09-20   | 51.0                   | 2017-02-15            | NaN       | 2018-02-16        | NaN                | 2020-03-27      | NaN              | 61.0                 | 62.0                  | TDF + 3TC + DTG | 2022-07-18           | EFV + FTC + TDF | 2017-09-20         | Yes                             | NaN              | NaN                   | 9550348bba5046a7807ea299324db23b | 0.0                | NaN             |
#
# In \[11\]:
#
#     Viral_df.tail()
#
# Out\[11\]:
#
# |       | PatientId | Sex | AGE | Religion  | Occupation | EducationalLevelAttained | CurrentMaritalStatus | ViralLoad_Result | ViralLoad_date | ArtStartDate | Duration_on_art_Months | Enrolled_In_Care_date | Who_Stage | BaseLine_CD4_date | Baseline_CD4_count | Recent_CD4_date | Recent_CD4_count | Last_Weight_Recorded | First_Weight_Recorded | Current_regimen | Current_regimen_date | first_regimen   | first_regimen_date | Client_had_Cotrimoxazole_before | Disclosed_Status | functional_status     | PatientGUID                      | DaysLate_for_Pharm | Presence_of_OIs |
# |-------|-----------|-----|-----|-----------|------------|--------------------------|----------------------|------------------|----------------|--------------|------------------------|-----------------------|-----------|-------------------|--------------------|-----------------|------------------|----------------------|-----------------------|-----------------|----------------------|-----------------|--------------------|---------------------------------|------------------|-----------------------|----------------------------------|--------------------|-----------------|
# | 10672 | 175625    | F   | 43  | UNKNOWN   | NaN        | Grade 12                 | M                    | 0                | 2020-04-09     | 2009-06-19   | 150.0                  | 2009-06-05            | 0.0       | 2009-06-05        | 126.0              | 2019-05-27      | NaN              | NaN                  | 51.0                  | TDF + 3TC + DTG | 2022-04-14           | EFV + FTC + TDF | 2009-06-19         | Yes                             | Yes              | NaN                   | 1d6788bde5fb469fb5f161bbd0e925a4 | 0.0                | NaN             |
# | 10673 | 178249    | F   | 41  | CHRISTIAN | NaN        | COLLEGE/UNIVERSITY       | S                    | 19               | 2020-08-28     | 2018-08-03   | 40.0                   | 2018-08-03            | NaN       | 2018-08-03        | 182.0              | 2018-08-03      | 182.0            | NaN                  | 50.0                  | TDF + 3TC + DTG | 2022-03-11           | EFV + 3TC + TDF | 2018-08-03         | NaN                             | No               | NaN                   | 1dd9b391e2034484b865654eb2dec236 | 16.0               | NaN             |
# | 10674 | 178249    | F   | 41  | CHRISTIAN | NaN        | COLLEGE/UNIVERSITY       | S                    | 0                | 2021-08-27     | 2018-08-03   | 40.0                   | 2018-08-03            | NaN       | 2018-08-03        | 182.0              | 2018-08-03      | 182.0            | NaN                  | 50.0                  | TDF + 3TC + DTG | 2022-03-11           | EFV + 3TC + TDF | 2018-08-03         | NaN                             | No               | NaN                   | 1dd9b391e2034484b865654eb2dec236 | 16.0               | NaN             |
# | 10675 | 993585    | F   | 22  | CHRISTIAN | NaN        | Grade 9                  | S                    | 26               | 2021-02-02     | 2021-06-29   | 6.0                    | 2018-06-06            | NaN       | NaT               | NaN                | NaT             | NaN              | NaN                  | NaN                   | TDF + 3TC + DTG | 2022-03-02           | TDF + 3TC + DTG | 2021-06-29         | NaN                             | NaN              | Healthy, able to work | a7255839349b4225bc5562c81e6d7dc7 | 0.0                | No              |
# | 10676 | 697669    | M   | 31  | CHRISTIAN | NaN        | Grade 12                 | S                    | 0                | 2021-10-02     | 2019-07-09   | 29.0                   | 2019-07-09            | NaN       | NaT               | NaN                | NaT             | NaN              | 64.0                 | 55.0                  | TDF + 3TC + DTG | 2022-03-26           | TDF + 3TC + EFV | 2019-07-09         | NaN                             | NaN              | Healthy, able to work | 7550797a4b7648ddbc0e913b9ce175de | 0.0                | No              |
#
# In \[12\]:
#
#     Viral_df.describe()
#
# Out\[12\]:
#
# |       | PatientId    | AGE          | Occupation | ViralLoad_Result | ViralLoad_date                | ArtStartDate        | Duration_on_art_Months | Enrolled_In_Care_date         | Who_Stage   | BaseLine_CD4_date             | Baseline_CD4_count | Recent_CD4_date               | Recent_CD4_count | Last_Weight_Recorded | First_Weight_Recorded | Current_regimen_date          | first_regimen_date            | DaysLate_for_Pharm |
# |-------|--------------|--------------|------------|------------------|-------------------------------|---------------------|------------------------|-------------------------------|-------------|-------------------------------|--------------------|-------------------------------|------------------|----------------------|-----------------------|-------------------------------|-------------------------------|--------------------|
# | count | 1.067700e+04 | 10677.000000 | 0.0        | 1.067700e+04     | 10677                         | 10624               | 10624.000000           | 10637                         | 5365.000000 | 8653                          | 4675.000000        | 8653                          | 3761.00000       | 5808.000000          | 7925.000000           | 10624                         | 10624                         | 10604.000000       |
# | mean  | 7.622993e+05 | 39.922544    | NaN        | 1.940361e+04     | 2021-02-17 05:45:48.300084224 | 2015-10-07 18:11:15 | 74.280591              | 2015-06-15 15:42:13.233054464 | 0.074557    | 2015-02-23 19:16:05.630417152 | 370.739679         | 2019-04-20 03:47:29.462614016 | 522.69875        | 66.056474            | 59.295016             | 2022-04-10 09:40:56.024096512 | 2015-10-06 06:34:33.795180544 | 7.383535           |
# | min   | 1.290000e+02 | 0.000000     | NaN        | 0.000000e+00     | 2020-03-01 00:00:00           | 2000-06-23 00:00:00 | -7.000000              | 2001-02-06 00:00:00           | 0.000000    | 2001-04-16 00:00:00           | 0.000000           | 2007-03-21 00:00:00           | 0.00000          | 0.000000             | 0.000000              | 2007-04-18 00:00:00           | 2000-06-23 00:00:00           | 0.000000           |
# | 25%   | 3.767650e+05 | 32.000000    | NaN        | 0.000000e+00     | 2020-09-08 00:00:00           | 2013-08-23 00:00:00 | 39.000000              | 2012-05-17 00:00:00           | 0.000000    | 2013-09-10 00:00:00           | 174.000000         | 2018-11-30 00:00:00           | 311.00000        | 55.000000            | 50.000000             | 2022-03-14 00:00:00           | 2013-08-23 00:00:00           | 0.000000           |
# | 50%   | 7.544340e+05 | 40.000000    | NaN        | 0.000000e+00     | 2021-03-10 00:00:00           | 2016-04-23 12:00:00 | 68.000000              | 2016-07-27 00:00:00           | 0.000000    | 2015-04-09 00:00:00           | 328.000000         | 2019-04-04 00:00:00           | 483.00000        | 63.000000            | 58.000000             | 2022-05-03 00:00:00           | 2016-04-19 12:00:00           | 0.000000           |
# | 75%   | 1.142294e+06 | 48.000000    | NaN        | 5.200000e+01     | 2021-08-09 00:00:00           | 2018-09-04 00:00:00 | 100.000000             | 2018-12-30 00:00:00           | 0.000000    | 2018-02-27 00:00:00           | 510.000000         | 2020-01-30 00:00:00           | 682.00000        | 75.000000            | 68.000000             | 2022-06-13 00:00:00           | 2018-09-04 00:00:00           | 3.000000           |
# | max   | 1.521857e+06 | 84.000000    | NaN        | 1.000000e+07     | 2021-12-30 00:00:00           | 2022-07-22 00:00:00 | 258.000000             | 2022-07-22 00:00:00           | 3.000000    | 2022-07-20 00:00:00           | 2417.000000        | 2022-07-20 00:00:00           | 2417.00000       | 643.000000           | 432.000000            | 2022-08-05 00:00:00           | 2022-07-22 00:00:00           | 4478.000000        |
# | std   | 4.427725e+05 | 11.843637    | NaN        | 2.834533e+05     | NaN                           | NaN                 | 44.918905              | NaN                           | 0.356096    | NaN                           | 269.430105         | NaN                           | 298.84818        | 23.453142            | 17.175389             | NaN                           | NaN                           | 58.036084          |
#
# In \[13\]:
#
#     Viral_df.isnull().sum()
#
# Out\[13\]:
#
#     PatientId                              0
#     Sex                                    0
#     AGE                                    0
#     Religion                            2119
#     Occupation                         10677
#     EducationalLevelAttained             732
#     CurrentMaritalStatus                1194
#     ViralLoad_Result                       0
#     ViralLoad_date                         0
#     ArtStartDate                          53
#     Duration_on_art_Months                53
#     Enrolled_In_Care_date                 40
#     Who_Stage                           5312
#     BaseLine_CD4_date                   2024
#     Baseline_CD4_count                  6002
#     Recent_CD4_date                     2024
#     Recent_CD4_count                    6916
#     Last_Weight_Recorded                4869
#     First_Weight_Recorded               2752
#     Current_regimen                       53
#     Current_regimen_date                  53
#     first_regimen                         53
#     first_regimen_date                    53
#     Client_had_Cotrimoxazole_before     3757
#     Disclosed_Status                    5025
#     functional_status                   7955
#     PatientGUID                            0
#     DaysLate_for_Pharm                    73
#     Presence_of_OIs                     7955
#     dtype: int64
#
# In \[14\]:
#
#     Viral_df.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 10677 entries, 0 to 10676
#     Data columns (total 29 columns):
#      #   Column                           Non-Null Count  Dtype
#     ---  ------                           --------------  -----
#      0   PatientId                        10677 non-null  int64
#      1   Sex                              10677 non-null  object
#      2   AGE                              10677 non-null  int64
#      3   Religion                         8558 non-null   object
#      4   Occupation                       0 non-null      float64
#      5   EducationalLevelAttained         9945 non-null   object
#      6   CurrentMaritalStatus             9483 non-null   object
#      7   ViralLoad_Result                 10677 non-null  int64
#      8   ViralLoad_date                   10677 non-null  datetime64[ns]
#      9   ArtStartDate                     10624 non-null  datetime64[ns]
#      10  Duration_on_art_Months           10624 non-null  float64
#      11  Enrolled_In_Care_date            10637 non-null  datetime64[ns]
#      12  Who_Stage                        5365 non-null   float64
#      13  BaseLine_CD4_date                8653 non-null   datetime64[ns]
#      14  Baseline_CD4_count               4675 non-null   float64
#      15  Recent_CD4_date                  8653 non-null   datetime64[ns]
#      16  Recent_CD4_count                 3761 non-null   float64
#      17  Last_Weight_Recorded             5808 non-null   float64
#      18  First_Weight_Recorded            7925 non-null   float64
#      19  Current_regimen                  10624 non-null  object
#      20  Current_regimen_date             10624 non-null  datetime64[ns]
#      21  first_regimen                    10624 non-null  object
#      22  first_regimen_date               10624 non-null  datetime64[ns]
#      23  Client_had_Cotrimoxazole_before  6920 non-null   object
#      24  Disclosed_Status                 5652 non-null   object
#      25  functional_status                2722 non-null   object
#      26  PatientGUID                      10677 non-null  object
#      27  DaysLate_for_Pharm               10604 non-null  float64
#      28  Presence_of_OIs                  2722 non-null   object
#     dtypes: datetime64[ns](7), float64(8), int64(3), object(11)
#     memory usage: 2.4+ MB
#
# In \[ \]:
#
#
#
# # EDA<a href="#EDA" class="anchor-link">¶</a>
#
# In \[15\]:
#
#     import seaborn as sns
#
# In \[16\]:
#
#     sns.distplot(Viral_df['AGE'])
#
# Out\[16\]:
#
#     <Axes: xlabel='AGE', ylabel='Density'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/fc245b04f7625cb0a3ecb08c44a277dcf5cb90fa.png)
#
# In \[17\]:
#
#     sns.displot(Viral_df['Sex'])
#
# Out\[17\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x14ff4f940>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/052bf7323c4ad5d28901b336e5bcfe4ed87c5860.png)
#
# In \[18\]:
#
#     sns.countplot(Viral_df['ViralLoad_Result'])
#
# Out\[18\]:
#
#     <Axes: ylabel='count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/9745870f970a9593f76ccad721ad5c62b3e70754.png)
#
# In \[19\]:
#
#     sns.histplot(Viral_df['EducationalLevelAttained'])
#
# Out\[19\]:
#
#     <Axes: xlabel='EducationalLevelAttained', ylabel='Count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/350bd65a89b46fe39174fc1d497832805a229b2e.png)
#
# In \[20\]:
#
#     sns.countplot(Viral_df['ViralLoad_Result'])
#
# Out\[20\]:
#
#     <Axes: ylabel='count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/9745870f970a9593f76ccad721ad5c62b3e70754.png)
#
# In \[21\]:
#
#     sns.displot(Viral_df['CurrentMaritalStatus'])
#
# Out\[21\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x1507e7c10>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/6ec45c4576649b06abaad91f30df01be63404eb7.png)
#
# In \[22\]:
#
#     sns.displot(Viral_df['Duration_on_art_Months'])
#
# Out\[22\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x1503b6710>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/2cc4349bafe9dc1da818c24decdfc8c326875b8e.png)
#
# In \[23\]:
#
#     sns.displot(Viral_df['Enrolled_In_Care_date'])
#
# Out\[23\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x15075e680>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/0cba9e2d78007cdbdf3e1146e2d03cb399750128.png)
#
# In \[24\]:
#
#     sns.displot(Viral_df['BaseLine_CD4_date'])
#
# Out\[24\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x15031afe0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/4340ab9a2e27904dac3ace3d44c55ef7d945263b.png)
#
# In \[25\]:
#
#     sns.displot(Viral_df['Baseline_CD4_count'])
#
# Out\[25\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x150207760>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/b49ba0d850a4fee74f6d7650c9530f4e7d77e91e.png)
#
# In \[26\]:
#
#     sns.displot(Viral_df['Recent_CD4_count'])
#
# Out\[26\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x1500ba0e0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/f37d2ad36be81eba14a296051427360e42be530e.png)
#
# In \[27\]:
#
#     sns.displot(Viral_df['Last_Weight_Recorded'])
#
# Out\[27\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x1501441c0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/aa66caade8eb98643af778752c97eaaca049adf8.png)
#
# In \[28\]:
#
#     sns.displot(Viral_df['First_Weight_Recorded'])
#
# Out\[28\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x15127c5b0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/716bb81f6ec4255c3edce2b0f85eeaabf2540ef1.png)
#
# In \[29\]:
#
#     sns.displot(Viral_df['Current_regimen'])
#
# Out\[29\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x15310f880>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/15739089d484e18135063a7647cab813081d2e71.png)
#
# In \[30\]:
#
#     sns.displot(Viral_df['Current_regimen_date'])
#
# Out\[30\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x1533a95a0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/1d0c50c31bbd63adf853e7dba7e18eb92bd810e0.png)
#
# In \[31\]:
#
#     sns.displot(Viral_df['first_regimen'])
#
# Out\[31\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x1533d7cd0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/99c0ec101c3700715f4d9d7567daa14099877102.png)
#
# In \[32\]:
#
#     sns.displot(Viral_df['first_regimen_date'])
#
# Out\[32\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x153beb130>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/7272382ef5315bf947c601922db5dbc443d3fc68.png)
#
# In \[33\]:
#
#     sns.displot(Viral_df['Client_had_Cotrimoxazole_before'])
#
# Out\[33\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x153e6dd80>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/6e87d9e3d2cf6cee37d863ac39b99df7af8e3685.png)
#
# In \[34\]:
#
#     sns.displot(Viral_df['Disclosed_Status'])
#
# Out\[34\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x153eda3b0>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/4876d583a6f79db5f5830c69b432992e05ff252e.png)
#
# In \[35\]:
#
#     sns.displot(Viral_df['functional_status'])
#
# Out\[35\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x153f3ea70>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/4c9cbcb90d0f60c01bcafbefe596985616dfc447.png)
#
# In \[36\]:
#
#     sns.countplot(Viral_df['DaysLate_for_Pharm'])
#
# Out\[36\]:
#
#     <Axes: ylabel='count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/9745870f970a9593f76ccad721ad5c62b3e70754.png)
#
# In \[37\]:
#
#     sns.displot(Viral_df['Presence_of_OIs'])
#
# Out\[37\]:
#
#     <seaborn.axisgrid.FacetGrid at 0x153e6fc40>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/018f8947a6e474e6c75d34e71a64bf2052743d66.png)
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# # UNIVARIATE OBSERVATIONS<a href="#UNIVARIATE-OBSERVATIONS" class="anchor-link">¶</a>
#
# 1.AGE - According to the descriptive statistics the count of the
# patients is a total of 10677 with a mean age of about 39 meaning that
# the average of the total age of this data set were adults of about 39.9
# years and the minimum age is about 0.0. The tells us that the youngest
# patients were less than 1 year old, and the maximum or eldest patients
# were around 84 years of age. Meanwhile 50% of the patients were around
# 40 years of age. This gives a descriptive statistics overview of the
# social demographic variable age.
#
# 1.  SEX - The total number of females about 7100 while the males are
#     about 3500. The number of females is higher than that of the males.
#
# 2.  Viral load Results- The total for viral load results is a total
#     count of about 10677 patients.
#
# 3.  Education level attainment - about patients on ARTs were graduates
#     with a total count of about 3000 making it the highest number of
#     patients in the dataset ,followed by
#
# 4.  Marital status- The current. Marital status has a total of are
#     married, followed by the single ones amounting to about 2700, while
#     the divorced and widowed are both at 1000.and lastly the unmarried
#     are the list at about 200.Theerfore the highest number of the
#     patients is among the married ones.
#
# 6.Duration on ART in Months -The chart below shows the Duration in
# Months for the patients on ARTs with a total of 250 months. It shows
# that they are 1400 ART patients that have been on ART for 100 months,
# and 600 ART patients have been on ARTs between 0-50 months, while the
# number has dropped between 50-100 months to about 500 patients. Lastly
# between 110-200 it has had a downward trend of about 200 and further
# dropped to 100 patients between 180 -200 months. However, they are no
# patients that fall around 250 months in terms of duration of being on
# ARTs in this dataset.
#
# 7.Enrollement in care date -Enrolment in care started to increase by
# 2004 though it was slow. Between 2004-2008 it rose to about slightly
# over 200
#
# 8.BaseLine_CD4_date -
#
# # BIVARIANT<a href="#BIVARIANT" class="anchor-link">¶</a>
#
# In \[38\]:
#
#     import seaborn as sns
#
#     import matplotlib.pyplot as plt
#
# In \[39\]:
#
#     sns.barplot(data= Viral_df, x= 'Sex' , y='ViralLoad_Result')
#
# Out\[39\]:
#
#     <Axes: xlabel='Sex', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/2bf906134bd7d4803daac26fd191d1a3a8d78de7.png)
#
# In \[40\]:
#
#     sns.barplot(data= Viral_df, x= 'Sex' , y='AGE',palette = 'deep')
#     sns.set_style('ticks')
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/81f8e20f95129c2b8b3043ffe92763219ab9893b.png)
#
# In \[41\]:
#
#     sns.barplot(data= Viral_df, x= 'Sex' , y='ViralLoad_Result')
#
# Out\[41\]:
#
#     <Axes: xlabel='Sex', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/13f4e6ddf64e3d6d68c5d2ea2bd8c66186b9fc85.png)
#
# In \[42\]:
#
#     sns.lineplot(data= Viral_df ,x='AGE', y='ViralLoad_Result')
#
# Out\[42\]:
#
#     <Axes: xlabel='AGE', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/da438ee608739cb075f377eb8f4b4a0913dfe3da.png)
#
# In \[43\]:
#
#     sns.barplot(data= Viral_df ,x='CurrentMaritalStatus', y='ViralLoad_Result')
#
# Out\[43\]:
#
#     <Axes: xlabel='CurrentMaritalStatus', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/d4dbcceb87d9612567b7d034cf057f7418562c70.png)
#
# In \[60\]:
#
#     sns.lineplot(data= Viral_df, x= 'Baseline_CD4_count', y='Recent_CD4_count')
#
# Out\[60\]:
#
#     <Axes: xlabel='Baseline_CD4_count', ylabel='Recent_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/c93a8619adf9cc30d65bc30b38824951fb3d2741.png)
#
# In \[62\]:
#
#     sns.lineplot(data= Viral_df, x= 'AGE', y='Recent_CD4_count')
#
# Out\[62\]:
#
#     <Axes: xlabel='AGE', ylabel='Recent_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/ef33cd34ae9bfa0ed5fe46e480a39cf7a9f0abdf.png)
#
# In \[46\]:
#
#     sns.barplot(data= Viral_df, x= 'Sex', y='Recent_CD4_count')
#
# Out\[46\]:
#
#     <Axes: xlabel='Sex', ylabel='Recent_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/fad6adaab1d64b9c094321220fe4597c365af8d2.png)
#
# In \[47\]:
#
#     sns.barplot(data= Viral_df, x= 'Sex', y='Baseline_CD4_count')
#
# Out\[47\]:
#
#     <Axes: xlabel='Sex', ylabel='Baseline_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/2cfea436e69e0d80cdea34e5e2a958fdbbf07988.png)
#
# In \[66\]:
#
#     # using lineplot
#     # adding palette, style and hue semantic
#     %matplotlib inline
#     sns.scatterplot( x = "Duration_on_art_Months", y = "Recent_CD4_count",
#                  hue = "ViralLoad_Result", data = Viral_df)
#     sns.set_style('ticks')
#     palette=['green','orange','blue']
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/b9d5d389f0e643cedef7fe9420a39ef639c73988.png)
#
# In \[50\]:
#
#     sns.barplot(data= Viral_df, x= 'Sex', y='Baseline_CD4_count')
#     sns.set_style('darkgrid')
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/75c4163218f69e20e0fed8cd951e2b1560162b05.png)
#
# In \[54\]:
#
#     sns.lineplot(data= Viral_df, x='AGE',y='Recent_CD4_count' ,hue='Sex')
#
# Out\[54\]:
#
#     <Axes: xlabel='AGE', ylabel='Recent_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/70383817690bfc6aba183fadfe69be2933e63f96.png)
#
# In \[ \]:
#
#
#
# In \[59\]:
#
#     sns.countplot(x='ViralLoad_Result',hue='first_regimen',data=Viral_df)
#
# Out\[59\]:
#
#     <Axes: xlabel='ViralLoad_Result', ylabel='count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/119869f32341679e4bb62621631b59de39e95f43.png)
#
# # BIVARIATE OBSERVATIONS<a href="#BIVARIATE-OBSERVATIONS" class="anchor-link">¶</a>
#
# In \[ \]:
#
#
#
# 1.  Sex and Viral load results-The viral load results for the males are
#     standing at about 3200 while the viral load results for the women
#     are standing at 1500. The number of males whoes viral load is above
#     1000 copies /ml is more than that of females.indicating issues of
#     viral failure amongest the males than the females.
#
# 2.  Sex and AGE - The graph on the males on average is around 40 years
#     while for the women it is around it is below 40 around 38 on avarage
#     but both males and females do have outlier ages such as 84 and
#     infants such as 0.0 years.
#
# 3.  AGE and Viral load results -The graph shows high results of viral
#     load results around
#
# 4.  current marital status and Viral load -The category with the highest
#     Viral load reults is the un married with about 3.0 secondly divorced
#     with 5.0 married with about 5.0 c,thirdly single 4.0 and lastly
#     widowed with about n1.0 as the lowest in the list of viral load
#     results and unmarried as the highest.
#
# 5.  Baseline CD4 count and Recent CD4 count 44.Age and Recent CD4 count
#     -
#
# # MULTIVARIATE<a href="#MULTIVARIATE" class="anchor-link">¶</a>
#
# In \[67\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="ViralLoad_Result",hue="Sex")
#
# Out\[67\]:
#
#     <Axes: xlabel='AGE', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/b5f608ed24cbdddc03cd05f41947160b8ea25294.png)
#
# In \[68\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="ViralLoad_Result",hue="EducationalLevelAttained")
#
# Out\[68\]:
#
#     <Axes: xlabel='AGE', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/2122af853ff10d95ee192c40486fe3cc57b3d981.png)
#
# In \[69\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="ViralLoad_Result",hue="CurrentMaritalStatus")
#
# Out\[69\]:
#
#     <Axes: xlabel='AGE', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/47daae251694ce564467e11cb49cef9f9aa90ba9.png)
#
# In \[71\]:
#
#     sns.lineplot(data=Viral_df, x="AGE",y="ViralLoad_Result",hue="Religion")
#
# Out\[71\]:
#
#     <Axes: xlabel='AGE', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/e4baffa7d767412049ac07037900750702c7be8a.png)
#
# In \[72\]:
#
#     sns.scatterplot(data=Viral_df, x="Sex",y="ViralLoad_Result",hue="CurrentMaritalStatus")
#
# Out\[72\]:
#
#     <Axes: xlabel='Sex', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/e04350fd074de3da2d102ccca860d35be534bbc6.png)
#
# In \[73\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="ViralLoad_Result",hue="Sex")
#
# Out\[73\]:
#
#     <Axes: xlabel='AGE', ylabel='ViralLoad_Result'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/b5f608ed24cbdddc03cd05f41947160b8ea25294.png)
#
# In \[74\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="Recent_CD4_count",hue="Sex")
#
# Out\[74\]:
#
#     <Axes: xlabel='AGE', ylabel='Recent_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/0062a4d447ecff2427ae336eb5bfcccde84fd625.png)
#
# In \[85\]:
#
#     sns.scatterplot(data=Viral_df, x="Duration_on_art_Months",y="Recent_CD4_count",hue="AGE")
#
# Out\[85\]:
#
#     <Axes: xlabel='Duration_on_art_Months', ylabel='Recent_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/0136aa9de49e964599c6bf2dc9eee77a79568d79.png)
#
# In \[86\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="Baseline_CD4_count",hue="Sex")
#
# Out\[86\]:
#
#     <Axes: xlabel='AGE', ylabel='Baseline_CD4_count'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/8b5c398c6cab37ee867f661a27170e125a5d453e.png)
#
# In \[87\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="Current_regimen",hue="Sex")
#
# Out\[87\]:
#
#     <Axes: xlabel='AGE', ylabel='Current_regimen'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/a79c5a449b38e9217f56758fd4103f935ca4652f.png)
#
# In \[88\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="Sex",hue="first_regimen")
#
# Out\[88\]:
#
#     <Axes: xlabel='AGE', ylabel='Sex'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/d74063430b8ca7cab8daeabcf60dc3780557b34b.png)
#
# In \[89\]:
#
#     sns.scatterplot(data=Viral_df, x="AGE",y="first_regimen",hue="Sex")
#
# Out\[89\]:
#
#     <Axes: xlabel='AGE', ylabel='first_regimen'>
#
# ![](attachment:vertopal_d9b6a539aed94167bef916cd36371c13/0b049953fbdfd720fd592b4a15c6238f382efd71.png)
#
# # Multivariate Observations<a href="#Multivariate-Observations" class="anchor-link">¶</a>
#
# # Inferencial statistics<a href="#Inferencial-statistics" class="anchor-link">¶</a>
